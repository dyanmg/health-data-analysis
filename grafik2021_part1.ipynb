# %%
import tabula.io as tb
import pandas as pd
import numpy as np
import math

# %%
file = 'Profil-Kesehatan-2021.pdf'
# file = 'https://github.com/dyanmg/health-data-analysis/raw/master/Profil-Kesehatan-Indonesia-Tahun-2020.pdf'
data = tb.read_pdf(file, area = (500, 0, 750, 700), pages = '8', multiple_tables = False)
data = data[0]
data
# Out:
#     GAMBAR 2.1    JUMLAH PUSKESMAS DI INDONESIA TAHUN 2016 - 2021    22
# 0   GAMBAR 2.2  RASIO PUSKESMAS PER KECAMATAN DI INDONESIA TAH...  23.0
# 1   GAMBAR 2.3  JUMLAH PUSKESMAS RAWAT INAP DAN NON RAWAT INAP...  24.0
# 2          NaN                                    TAHUN 2017-2021   NaN
# 3   GAMBAR 2.4  PERSENTASE PUSKESMAS DENGAN 9 (SEMBILAN) SESUA...  25.0
# 4          NaN       TENAGA KESEHATAN MENURUT PROVINSI TAHUN 2021   NaN
# 5   GAMBAR 2.5  PERSENTASE PUSKESMAS TANPA DOKTER MENURUT PROV...  26.0
# 6          NaN                                               2021   NaN
# 7   GAMBAR 2.6  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  28.0
# 8          NaN                        MENURUT PROVINSI TAHUN 2021   NaN
# 9   GAMBAR 2.7  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  29.0
# 10         NaN                        MENURUT PROVINSI TAHUN 2021   NaN
# 11  GAMBAR 2.8  JUMLAH PELAKSANAAN KESEHATAN KERJA DI TEMPAT K...  30.0
# 12         NaN                                         TAHUN 2021   NaN
# 13  GAMBAR 2.9  JUMLAH PELAKSANAAN KESEHATAN OLAHRAGA DI INDON...  31.0
# 14         NaN                                               2021   NaN

# %%
cols = data.columns
added = pd.concat((cols.to_frame().T, data))
added
# Out:
#     GAMBAR 2.1    JUMLAH PUSKESMAS DI INDONESIA TAHUN 2016 - 2021    22
# 0   GAMBAR 2.1    JUMLAH PUSKESMAS DI INDONESIA TAHUN 2016 - 2021    22
# 0   GAMBAR 2.2  RASIO PUSKESMAS PER KECAMATAN DI INDONESIA TAH...  23.0
# 1   GAMBAR 2.3  JUMLAH PUSKESMAS RAWAT INAP DAN NON RAWAT INAP...  24.0
# 2          NaN                                    TAHUN 2017-2021   NaN
# 3   GAMBAR 2.4  PERSENTASE PUSKESMAS DENGAN 9 (SEMBILAN) SESUA...  25.0
# 4          NaN       TENAGA KESEHATAN MENURUT PROVINSI TAHUN 2021   NaN
# 5   GAMBAR 2.5  PERSENTASE PUSKESMAS TANPA DOKTER MENURUT PROV...  26.0
# 6          NaN                                               2021   NaN
# 7   GAMBAR 2.6  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  28.0
# 8          NaN                        MENURUT PROVINSI TAHUN 2021   NaN
# 9   GAMBAR 2.7  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  29.0
# 10         NaN                        MENURUT PROVINSI TAHUN 2021   NaN
# 11  GAMBAR 2.8  JUMLAH PELAKSANAAN KESEHATAN KERJA DI TEMPAT K...  30.0
# 12         NaN                                         TAHUN 2021   NaN
# 13  GAMBAR 2.9  JUMLAH PELAKSANAAN KESEHATAN OLAHRAGA DI INDON...  31.0
# 14         NaN                                               2021   NaN

# %%
added.columns = np.arange(3)
added
# Out:
#              0                                                  1     2
# 0   GAMBAR 2.1    JUMLAH PUSKESMAS DI INDONESIA TAHUN 2016 - 2021    22
# 0   GAMBAR 2.2  RASIO PUSKESMAS PER KECAMATAN DI INDONESIA TAH...  23.0
# 1   GAMBAR 2.3  JUMLAH PUSKESMAS RAWAT INAP DAN NON RAWAT INAP...  24.0
# 2          NaN                                    TAHUN 2017-2021   NaN
# 3   GAMBAR 2.4  PERSENTASE PUSKESMAS DENGAN 9 (SEMBILAN) SESUA...  25.0
# 4          NaN       TENAGA KESEHATAN MENURUT PROVINSI TAHUN 2021   NaN
# 5   GAMBAR 2.5  PERSENTASE PUSKESMAS TANPA DOKTER MENURUT PROV...  26.0
# 6          NaN                                               2021   NaN
# 7   GAMBAR 2.6  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  28.0
# 8          NaN                        MENURUT PROVINSI TAHUN 2021   NaN
# 9   GAMBAR 2.7  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  29.0
# 10         NaN                        MENURUT PROVINSI TAHUN 2021   NaN
# 11  GAMBAR 2.8  JUMLAH PELAKSANAAN KESEHATAN KERJA DI TEMPAT K...  30.0
# 12         NaN                                         TAHUN 2021   NaN
# 13  GAMBAR 2.9  JUMLAH PELAKSANAAN KESEHATAN OLAHRAGA DI INDON...  31.0
# 14         NaN                                               2021   NaN

# %%
def my_isnan(var):
    return type(var) == float and math.isnan(var)
    
selected = []
carry_texts = []
for index, row in added[::-1].iterrows():
    if my_isnan(row[0]):
        carry_texts.insert(0, row[1])
    elif len(carry_texts) > 0:
        carry_texts.insert(0, row[1])
        row[1] = ' '.join(carry_texts)
        carry_texts = []
        selected.insert(0, row)
    else:
        selected.insert(0, row)
filtered = pd.DataFrame(selected)
filtered
# Out:
#              0                                                  1     2
# 0   GAMBAR 2.1    JUMLAH PUSKESMAS DI INDONESIA TAHUN 2016 - 2021    22
# 0   GAMBAR 2.2  RASIO PUSKESMAS PER KECAMATAN DI INDONESIA TAH...  23.0
# 1   GAMBAR 2.3  JUMLAH PUSKESMAS RAWAT INAP DAN NON RAWAT INAP...  24.0
# 3   GAMBAR 2.4  PERSENTASE PUSKESMAS DENGAN 9 (SEMBILAN) SESUA...  25.0
# 5   GAMBAR 2.5  PERSENTASE PUSKESMAS TANPA DOKTER MENURUT PROV...  26.0
# 7   GAMBAR 2.6  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  28.0
# 9   GAMBAR 2.7  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  29.0
# 11  GAMBAR 2.8  JUMLAH PELAKSANAAN KESEHATAN KERJA DI TEMPAT K...  30.0
# 13  GAMBAR 2.9  JUMLAH PELAKSANAAN KESEHATAN OLAHRAGA DI INDON...  31.0

# %%
new_index = filtered.reset_index(drop=True)
new_index[2] = new_index[2].astype(np.int_)
new_index
# Out:
#             0                                                  1   2
# 0  GAMBAR 2.1    JUMLAH PUSKESMAS DI INDONESIA TAHUN 2016 - 2021  22
# 1  GAMBAR 2.2  RASIO PUSKESMAS PER KECAMATAN DI INDONESIA TAH...  23
# 2  GAMBAR 2.3  JUMLAH PUSKESMAS RAWAT INAP DAN NON RAWAT INAP...  24
# 3  GAMBAR 2.4  PERSENTASE PUSKESMAS DENGAN 9 (SEMBILAN) SESUA...  25
# 4  GAMBAR 2.5  PERSENTASE PUSKESMAS TANPA DOKTER MENURUT PROV...  26
# 5  GAMBAR 2.6  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  28
# 6  GAMBAR 2.7  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...  29
# 7  GAMBAR 2.8  JUMLAH PELAKSANAAN KESEHATAN KERJA DI TEMPAT K...  30
# 8  GAMBAR 2.9  JUMLAH PELAKSANAAN KESEHATAN OLAHRAGA DI INDON...  31

# %%
new_index.columns = ['gambar', 'judul', 'halaman']
final = new_index.set_index('gambar')
final
# Out:
#                                                         judul  halaman
# gambar
# GAMBAR 2.1    JUMLAH PUSKESMAS DI INDONESIA TAHUN 2016 - 2021       22
# GAMBAR 2.2  RASIO PUSKESMAS PER KECAMATAN DI INDONESIA TAH...       23
# GAMBAR 2.3  JUMLAH PUSKESMAS RAWAT INAP DAN NON RAWAT INAP...       24
# GAMBAR 2.4  PERSENTASE PUSKESMAS DENGAN 9 (SEMBILAN) SESUA...       25
# GAMBAR 2.5  PERSENTASE PUSKESMAS TANPA DOKTER MENURUT PROV...       26
# GAMBAR 2.6  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...       28
# GAMBAR 2.7  JUMLAH KABUPATEN/KOTA YANG MELAKSANAKAN KESEHA...       29
# GAMBAR 2.8  JUMLAH PELAKSANAAN KESEHATAN KERJA DI TEMPAT K...       30
# GAMBAR 2.9  JUMLAH PELAKSANAAN KESEHATAN OLAHRAGA DI INDON...       31

# %%
final.to_csv('output/grafik2021_part1.csv')

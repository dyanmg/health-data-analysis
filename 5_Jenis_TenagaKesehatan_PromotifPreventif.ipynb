# %%
import tabula.io as tb
import pandas as pd
import numpy as np
import math

# %%
file = 'Profil-Kesehatan-Indonesia-Tahun-2020.pdf'
# file = 'https://github.com/dyanmg/health-data-analysis/raw/master/Profil-Kesehatan-Indonesia-Tahun-2020.pdf'
data = tb.read_pdf(file, area = (20, 0, 465, 510), pages = '57')
df = data[0]
df.columns = np.arange(1)
# jakarta = df.iloc[2,:]
df = df.iloc[4:]
df

df[1] = df[0].str.split(' ').str[-1]
df[0] = df[0].str.split(' ').str[:-1].str.join(' ')
df
# Out:
# C:\Users\satria.rahman\AppData\Local\Temp\ipykernel_18416\2400561933.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[1] = df[0].str.split(' ').str[-1]
# C:\Users\satria.rahman\AppData\Local\Temp\ipykernel_18416\2400561933.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[0] = df[0].str.split(' ').str[:-1].str.join(' ')
#                             0     1
# 4   Kepulauan Bangka Belitung  92,2
# 5               DI Yogyakarta  89,3
# 6                 Jawa Tengah  81,2
# ...

# %%
# df[2] = df[0].str.split(' ')
# df[2] = df[0].str.split(' ').str[-1].str.replace(',', '.')
# process = df.copy()
# process['Gabung'] = process[0] + " " + process[1].fillna('')
# process[0]

#process[1] = process[0].str.split(' ').str[-1]
#process[0] = process[0].str.split(' ').str[:-1].str.join(' ')
# process

# concat = df.copy()
# split = concat[0].str.split(' ')
# isna = concat[1].isna()
# concat.loc[isna, 1] = split.str[-1]
# concat.loc[isna, 0] = split.str[:-1].str.join(' ')
# concat
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2131, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2140, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# concat = pd.concat([concat.to_frame().T, process])
# concat

# %%
# final = concat.copy()
# final[1] = final[1].str.replace(',', '.', regex=False).astype(np.double)
# final.columns = ['provinsi', 'persentase akreditasi puskesmas']
# # final.reset_index(drop=True, inplace=True)
# final.set_index('provinsi', inplace=True)
# final = final[1:]
# final

final = df.copy()
final[1] = final[1].str.replace(',', '.', regex=False).astype(np.double)
final.columns = ['provinsi', '5 Jenis Tenaga Kesehatan Promotif Preventif']
# final.reset_index(drop=True, inplace=True)
final.set_index('provinsi', inplace=True)

final
# Out:
#                            5 Jenis Tenaga Kesehatan Promotif Preventif
# provinsi
# Kepulauan Bangka Belitung                                         92.2
# DI Yogyakarta                                                     89.3
# Jawa Tengah                                                       81.2
# Kalimantan Selatan                                                80.9
# Nusa Tenggara Barat                                               76.9
# Sumatera Barat                                                    73.7
# Kalimantan Utara                                                  69.0
# Kalimantan Timur                                                  65.2
# Aceh                                                              62.7
# Kalimantan Barat                                                  60.6
# Sulawesi Tengah                                                   59.4
# Sulawesi Selatan                                                  59.2
# ...

# %%
final.to_csv('output/5_Jenis_TenagaKerja_PromotifPreventif.csv')

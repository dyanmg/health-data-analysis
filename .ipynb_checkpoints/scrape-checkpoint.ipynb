# %%
import tabula
import pandas

# %%
file = 'Profil-Kesehatan-Indonesia-Tahun-2020.pdf'
data = tabula.read_pdf(file, area = (430, 94, 746, 518), pages = '38')
data
# Out:
# [                              0                   1           2   3  \
#  0                           NaN                 NaN   Laki-Laki NaN
#  1                   Lahir Hidup                   -           - NaN
#  2                          Bayi             0 Tahun   2.381.409 NaN
#  3     Batita (Bawah Tiga Tahun)         0 – 2 Tahun   7.161.120 NaN
#  4                   Anak Balita         1 – 4 Tahun   9.598.795 NaN
#  5     Balita (Bawah Lima Tahun)         0 – 4 Tahun  11.980.204 NaN
#  6                   Pra Sekolah         5 – 6 Tahun   4.857.859 NaN
#  7             Anak Usia Kelas 1                 NaN         NaN NaN
#  8                           NaN             7 Tahun   2.442.881 NaN
#  9                  SD/Setingkat                 NaN         NaN NaN
#  10       Anak Usia SD/Setingkat        7 – 12 Tahun  14.567.981 NaN
#  11           Penduduk Usia Muda          < 15 Tahun  36.130.351 NaN
#  12      Penduduk Usia Produktif       15 – 64 Tahun  92.188.550 NaN
# ...

# %%
df = data[0]
df
# Out:
#                               0                   1           2   3  \
# 0                           NaN                 NaN   Laki-Laki NaN
# 1                   Lahir Hidup                   -           - NaN
# 2                          Bayi             0 Tahun   2.381.409 NaN
# 3     Batita (Bawah Tiga Tahun)         0 – 2 Tahun   7.161.120 NaN
# 4                   Anak Balita         1 – 4 Tahun   9.598.795 NaN
# 5     Balita (Bawah Lima Tahun)         0 – 4 Tahun  11.980.204 NaN
# 6                   Pra Sekolah         5 – 6 Tahun   4.857.859 NaN
# 7             Anak Usia Kelas 1                 NaN         NaN NaN
# 8                           NaN             7 Tahun   2.442.881 NaN
# 9                  SD/Setingkat                 NaN         NaN NaN
# 10       Anak Usia SD/Setingkat        7 – 12 Tahun  14.567.981 NaN
# 11           Penduduk Usia Muda          < 15 Tahun  36.130.351 NaN
# 12      Penduduk Usia Produktif       15 – 64 Tahun  92.188.550 NaN
# ...

# %%
clean = df[[0,1,2,4,5]].iloc[1:]
clean
# Out:
#                               0                   1           2           4  \
# 1                   Lahir Hidup                   -           -           -
# 2                          Bayi             0 Tahun   2.381.409   2.280.969
# 3     Batita (Bawah Tiga Tahun)         0 – 2 Tahun   7.161.120   6.866.989
# 4                   Anak Balita         1 – 4 Tahun   9.598.795   9.214.585
# 5     Balita (Bawah Lima Tahun)         0 – 4 Tahun  11.980.204  11.495.554
# 6                   Pra Sekolah         5 – 6 Tahun   4.857.859   4.670.547
# 7             Anak Usia Kelas 1                 NaN         NaN         NaN
# 8                           NaN             7 Tahun   2.442.881   2.350.677
# 9                  SD/Setingkat                 NaN         NaN         NaN
# 10       Anak Usia SD/Setingkat        7 – 12 Tahun  14.567.981  13.927.519
# 11           Penduduk Usia Muda          < 15 Tahun  36.130.351  34.579.453
# ...

# %%
list = []
for index, row in clean.iterrows():
    list.append(row)
list
# Out:
# [0          NaN
#  1          NaN
#  2    Laki-Laki
#  3          NaN
#  4    Perempuan
#  5          NaN
#  Name: 0, dtype: object,
#  0    Lahir Hidup
#  1              -
#  2              -
#  3            NaN
#  4              -
#  5      4.747.077
#  Name: 1, dtype: object,
#  0         Bayi
#  1      0 Tahun
#  2    2.381.409
#  3          NaN
#  4    2.280.969
#  5    4.662.378
#  Name: 2, dtype: object,
#  0    Batita (Bawah Tiga Tahun)
#  1                  0 – 2 Tahun
#  2                    7.161.120
#  3                          NaN
#  4                    6.866.989
#  5                   14.028.109
#  Name: 3, dtype: object,
#  0    Anak Balita
#  1    1 – 4 Tahun
#  2      9.598.795
#  3            NaN
#  4      9.214.585
#  5     18.813.380
#  Name: 4, dtype: object,
#  0    Balita (Bawah Lima Tahun)
#  1                  0 – 4 Tahun
#  2                   11.980.204
#  3                          NaN
#  4                   11.495.554
#  5                   23.475.758
# ...

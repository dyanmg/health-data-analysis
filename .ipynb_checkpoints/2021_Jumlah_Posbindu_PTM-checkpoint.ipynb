# %%
import tabula.io as tb
import pandas as pd
import numpy as np
import math

# %%
file = 'Profil-Kesehatan-2021.pdf'
# file = 'https://github.com/dyanmg/health-data-analysis/raw/master/Profil-Kesehatan-Indonesia-Tahun-2020.pdf'
data = tb.read_pdf(file, area = (30, 0, 530, 510), pages = '87')
df = data[0]
df.columns = np.arange(1)
# jakarta = df.iloc[2,:]
# df = df.iloc[16:]
df

df[1] = df[0].str.split(' ').str[-1]
df[0] = df[0].str.split(' ').str[:-1].str.join(' ')
df = df[3:]
df

# concat = df.copy()
# split = concat[0].str.split(' ')
# isna = concat[1].isna()
# concat.loc[isna, 1] = split.str[-1]
# concat.loc[isna, 0] = split.str[:-1].str.join(' ') 
# concat = concat[2:]
# concat
# Out:
#                                          0      1
# 3                             Maluku Utara  100,0
# 4                                   Maluku  100,0
# 5                           Sulawesi Barat  100,0
# 6                                Gorontalo  100,0
# 7                        Sulawesi Tenggara  100,0
# 8                         Sulawesi Selatan  100,0
# 9                          Sulawesi Tengah  100,0
# 10                          Sulawesi Utara  100,0
# 11                        Kalimantan Utara  100,0
# 12                        Kalimantan Timur  100,0
# 13                        Kalimantan Barat  100,0
# 14  Nusa Tenggara Barat Target 2021  : 95%  100,0
# 15                         D.I. Yogyakarta  100,0
# 16                             DKI Jakarta  100,0
# 17                          Kepulauan Riau  100,0
# 18               Kepulauan Bangka Belitung  100,0
# 19                                Bengkulu  100,0
# 20                        Sumatera Selatan  100,0
# 21                          Sumatera Barat  100,0
# 22                                  Banten   99,6
# 23                                    Riau   99,1
# 24                              Jawa Timur   98,2
# 25                      Kalimantan Selatan   97,5
# 26                                   Papua   97,3
# 27                                    Aceh   96,1
# 28                                    Bali   95,8
# 29                                 Lampung   95,8
# 30                                   Jambi   93,6
# 31                       Kalimantan Tengah   93,5
# 32                              Jawa Barat   92,6
# 33                     Nusa Tenggara Timur   92,5
# 34                          Sumatera Utara   91,9
# 35                             Jawa Tengah   82,3
# 36                             Papua Barat   70,3

# %%
# df[2] = df[0].str.split(' ')
# df[2] = df[0].str.split(' ').str[-1].str.replace(',', '.')
# process = df.copy()
# process['Gabung'] = process[0] + " " + process[1].fillna('')
# process[0]

#process[1] = process[0].str.split(' ').str[-1]
#process[0] = process[0].str.split(' ').str[:-1].str.join(' ')
# process

# concat = df.copy()
# split = concat[0].str.split(' ')
# isna = concat[1].isna()
# concat.loc[isna, 1] = split.str[-1]
# concat.loc[isna, 0] = split.str[:-1].str.join(' ')
# concat
# Out:
#                             0      1
# 1                   Indonesia   89,7
# 2            Kalimantan Utara  100,0
# 3                        Bali  100,0
# 4               DI Yogyakarta  100,0
# 5   Kepulauan Bangka Belitung  100,0
# 6                    Bengkulu  100,0
# 7                  Jawa Timur   99,5
# 8                 Jawa Tengah   99,4
# 9                   Gorontalo   98,9
# 10         Kalimantan Selatan   98,7
# 11           Sulawesi Selatan   98,5
# 12             Sumatera Barat   98,2
# 13           Kalimantan Timur   97,3
# 14           Sumatera Selatan   97,1
# 15            Sulawesi Tengah   95,7
# 16                 Jawa Barat   94,9
# 17                    Lampung   94,9
# 18          Kalimantan Tengah   94,6
# 19             Kepulauan Riau   94,3
# 20                     Banten   94,3
# 21        Nusa Tenggara Barat   93,7
# 22           Kalimantan Barat   93,5
# 23                       Aceh   92,8
# 24                       Riau   92,6
# 25             Sumatera Utara   91,9
# 26                      Jambi   90,8
# 27          Sulawesi Tenggara   90,1
# 28        Nusa Tenggara Timur   89,5
# 29             Sulawesi Barat   88,5
# 30             Sulawesi Utara   86,7
# 31               Maluku Utara   76,9
# 32                     Maluku   72,6
# 33                DKI Jakarta   47,9
# 34                Papua Barat   44,7
# 35                      Papua   28,0

# %%
# concat = pd.concat([concat.to_frame().T, process])
# concat

# %%
final = df.copy()
final[1] = final[1].str.replace(',', '.', regex=False).astype(np.double)
final.columns = ['provinsi', 'Persentase Puskesmas dengan Ketersediaan Vaksin IDL']
# final.reset_index(drop=True, inplace=True)
final.set_index('provinsi', inplace=True)
final
# Out:
#                                         Persentase Puskesmas dengan Ketersediaan Vaksin IDL
# provinsi
# Maluku Utara                                                                        100.0
# Maluku                                                                              100.0
# Sulawesi Barat                                                                      100.0
# Gorontalo                                                                           100.0
# Sulawesi Tenggara                                                                   100.0
# Sulawesi Selatan                                                                    100.0
# Sulawesi Tengah                                                                     100.0
# Sulawesi Utara                                                                      100.0
# Kalimantan Utara                                                                    100.0
# Kalimantan Timur                                                                    100.0
# Kalimantan Barat                                                                    100.0
# Nusa Tenggara Barat Target 2021  : 95%                                              100.0
# D.I. Yogyakarta                                                                     100.0
# DKI Jakarta                                                                         100.0
# Kepulauan Riau                                                                      100.0
# Kepulauan Bangka Belitung                                                           100.0
# Bengkulu                                                                            100.0
# Sumatera Selatan                                                                    100.0
# Sumatera Barat                                                                      100.0
# Banten                                                                               99.6
# Riau                                                                                 99.1
# Jawa Timur                                                                           98.2
# Kalimantan Selatan                                                                   97.5
# Papua                                                                                97.3
# Aceh                                                                                 96.1
# Bali                                                                                 95.8
# Lampung                                                                              95.8
# Jambi                                                                                93.6
# Kalimantan Tengah                                                                    93.5
# Jawa Barat                                                                           92.6
# Nusa Tenggara Timur                                                                  92.5
# Sumatera Utara                                                                       91.9
# Jawa Tengah                                                                          82.3
# Papua Barat                                                                          70.3

# %%
final.to_csv('output/2021_Persentase_Puskesmas_Dengan_Ketersediaan_Vaksin_IDL.csv')
